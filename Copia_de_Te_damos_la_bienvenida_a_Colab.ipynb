# %%
dia_nac = int(input("Día de nacimiento: "))
mes_nac = int(input("Mes de nacimiento: "))
año_nac = int(input("Año de nacimiento: "))

dia_act = int(input("Día actual: "))
mes_act = int(input("Mes actual: "))
año_act = int(input("Año actual: "))

edad = año_act - año_nac

cumple_este_año = año_act * 10000 + mes_nac * 100 + dia_nac
fecha_actual = año_act * 10000 + mes_act * 100 + dia_act

no_cumplio = (cumple_este_año - fecha_actual) // 100000000 + 1
edad = edad - no_cumplio

print("Edad", edad)
# Out:
# Día de nacimiento: 21
# Mes de nacimiento: 1
# Año de nacimiento: 2006
# Día actual: 22
# Mes actual: 1
# Año actual: 2026
# Edad 20

# %%
print("Cálculo de edad (solo años)")

dia_nac = int(input("Día de nacimiento: "))
mes_nac = int(input("Mes de nacimiento: "))
año_nac = int(input("Año de nacimiento: "))

dia_act = int(input("Día actual: "))
mes_act = int(input("Mes actual: "))
año_act = int(input("Año actual: "))

edad = año_act - año_nac

if mes_act < mes_nac:
          edad = edad -1

if mes_act == mes_nac:
 if dia_act < dia_nac:
  edad = edad -1

print("Tu edad es:", edad, "años")
# Out:
# Cálculo de edad (solo años)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3692070126.py in <cell line: 0>()
#       1 print("Cálculo de edad (solo años)")
#       2
# ----> 3 dia_nac = int(input("Día de nacimiento: "))
#       4 mes_nac = int(input("Mes de nacimiento: "))
#       5 año_nac = int(input("Año de nacimiento: "))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
print("primer valor * segundo valor = c")
a = int(input("primer valor: "))
b = int(input("segundo valor: "))
resultado = a * b


if (resultado>=100):
  print(resultado)
# Out:
# primer valor * segundo valor = c
# primer valor: 50
# segundo valor: 2
# 100
